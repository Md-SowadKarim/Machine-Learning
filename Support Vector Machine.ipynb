# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('credit card.csv')
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1  24.0      2      2     -1
# 1          2   120000.0    2          2         2  26.0     -1      2      0
# 2          3    90000.0    2          2         2   NaN      0      0      0
# 3          4    50000.0    2          2         1   NaN      0      0      0
# 4          5    50000.0    1          2         1  57.0     -1      0     -1
# ...      ...        ...  ...        ...       ...   ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1  39.0      0      0      0
# 29996  29997   150000.0    1          3         2  43.0     -1     -1     -1
# 29997  29998    30000.0    1          2         2  37.0      4      3      2
# 29998  29999    80000.0    1          3         1  41.0      1     -1      0
# 29999  30000    50000.0    1          2         1  46.0      0      0      0
#
# ...

# %% [markdown]
# # Shape view

# %%
df.shape
# Out:
# (30000, 25)

# %% [markdown]
# #  NUll Value Checking

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           2
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %% [markdown]
# # Null Value Handaling

# %%
handle=df['AGE'].mean()
handle
# Out:
# 35.48549903326889

# %%
df.AGE=df.AGE.fillna(handle)
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE        AGE  PAY_0  PAY_2  \
# 0          1    20000.0    2          2         1  24.000000      2      2
# 1          2   120000.0    2          2         2  26.000000     -1      2
# 2          3    90000.0    2          2         2  35.485499      0      0
# 3          4    50000.0    2          2         1  35.485499      0      0
# 4          5    50000.0    1          2         1  57.000000     -1      0
# ...      ...        ...  ...        ...       ...        ...    ...    ...
# 29995  29996   220000.0    1          3         1  39.000000      0      0
# 29996  29997   150000.0    1          3         2  43.000000     -1     -1
# 29997  29998    30000.0    1          2         2  37.000000      4      3
# 29998  29999    80000.0    1          3         1  41.000000      1     -1
# 29999  30000    50000.0    1          2         1  46.000000      0      0
#
# ...

# %% [markdown]
# # Initializing value of x & y

# %%
x=df.drop(['default.payment.next.month'],axis=1)
x
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE        AGE  PAY_0  PAY_2  \
# 0          1    20000.0    2          2         1  24.000000      2      2
# 1          2   120000.0    2          2         2  26.000000     -1      2
# 2          3    90000.0    2          2         2  35.485499      0      0
# 3          4    50000.0    2          2         1  35.485499      0      0
# 4          5    50000.0    1          2         1  57.000000     -1      0
# ...      ...        ...  ...        ...       ...        ...    ...    ...
# 29995  29996   220000.0    1          3         1  39.000000      0      0
# 29996  29997   150000.0    1          3         2  43.000000     -1     -1
# 29997  29998    30000.0    1          2         2  37.000000      4      3
# 29998  29999    80000.0    1          3         1  41.000000      1     -1
# 29999  30000    50000.0    1          2         1  46.000000      0      0
#
# ...

# %%
y=df['default.payment.next.month']
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 29995    0
# 29996    0
# 29997    1
# 29998    1
# 29999    1
# Name: default.payment.next.month, Length: 30000, dtype: int64

# %% [markdown]
# # Spliting Data For Train & Test

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=10)

# %%
x_train
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  PAY_3  \
# 19147  19148   200000.0    2          3         2  29.0     -1     -1     -1
# 5380    5381    20000.0    1          2         2  23.0      1      2      0
# 15486  15487   180000.0    1          2         2  43.0     -1     -1     -2
# 19794  19795   180000.0    2          2         1  39.0     -1     -1      0
# 11102  11103   290000.0    2          2         2  29.0     -2     -1     -1
# ...      ...        ...  ...        ...       ...   ...    ...    ...    ...
# 28017  28018   240000.0    2          2         2  27.0      0     -1      0
# 17728  17729    50000.0    2          2         1  51.0      0      0      2
# 29199  29200    10000.0    1          2         2  27.0      0      0      0
# 7293    7294   100000.0    2          2         1  27.0     -2     -2     -2
# 17673  17674   320000.0    2          2         2  35.0     -1      0      0
#
# ...

# %%
y_test
# Out:
# 20412    0
# 1296     0
# 3906     0
# 20454    0
# 5200     1
#         ..
# 20777    0
# 25221    1
# 23507    0
# 8582     1
# 24886    1
# Name: default.payment.next.month, Length: 9000, dtype: int64

# %% [markdown]
# # Model With Support vectior machine (SVC)

# %%
model=SVC()

# %%
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
model.score(x_test,y_test)
# Out:
# 0.7757777777777778

# %% [markdown]
# # Model with Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier(n_estimators=50) # with n_estimatiors=(500)tree number

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=50)

# %%
rfc.score(x_test,y_test)
# Out:
# 0.8178888888888889

# %% [markdown]
# # Model with Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtc.score(x_test,y_test)
# Out:
# 0.7205555555555555

# %% [markdown]
# # Naive Bayes

# %% [markdown]
# # Gassian ======

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb=GaussianNB()

# %%
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
gnb.score(x_test,y_test)
# Out:
# 0.37177777777777776

# %% [markdown]
# # Bernulli ======

# %%
from sklearn.naive_bayes import BernoulliNB
bnb=BernoulliNB()
bnb.fit(x_train,y_train)
bnb.score(x_test,y_test)
# Out:
# 0.7704444444444445

# %%
from sklearn.naive_bayes import MultinomialNB
mnb=MultinomialNB()
mnb.fit(x_train,y_train)
mnb.score(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-e21e1354969d> in <module>
#       1 from sklearn.naive_bayes import MultinomialNB
#       2 mnb=MultinomialNB()
# ----> 3 mnb.fit(x_train,y_train)
#       4 mnb.score(x_test,y_test)
#
# ~\anaconda3\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     639
#     640         self._init_counters(n_effective_classes, n_features)
# --> 641         self._count(X, Y)
#     642         alpha = self._check_alpha()
#     643         self._update_feature_log_prob(alpha)
#
# ~\anaconda3\lib\site-packages\sklearn\naive_bayes.py in _count(self, X, Y)
#     761     def _count(self, X, Y):
#     762         """Count and smooth feature occurrences."""
# --> 763         check_non_negative(X, "MultinomialNB (input X)")
#     764         self.feature_count_ += safe_sparse_dot(Y.T, X)
# ...
